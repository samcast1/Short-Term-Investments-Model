# %% [markdown]
# <a href="https://colab.research.google.com/github/samcast1/Short-Term-Investments-Model/blob/main/notebooks/3.1_sc_organizing_metrics_by_city.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Organizing Metrics By City
# ### Automated data transformations
#
# I have several metrics taken over time for hundreds of cities - Each of these metrics will be involved in the multivariate time-series forecast, so I need to get each city in its own dataframe.
#
# Dataframes will be indexed by date and contain 1 column for each metric.
#
# Since I'm working with ~700 cities, I'll need to automate this somehow.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re
warnings.filterwarnings('ignore')

# %%
cut_price_shares = pd.read_csv('cut_price_shares.csv')
days_to_pending = pd.read_csv('days_to_pending.csv')
market_heat = pd.read_csv('market_heat.csv')
price_cut = pd.read_csv('price_cut.csv')
sales_to_list = pd.read_csv('sales_to_list.csv')
sales_values = pd.read_csv('sales_values.csv')
zhdf_bot = pd.read_csv('zhdf_bot.csv')
zhdf_top = pd.read_csv('zhdf_top.csv')
zhdf_mid = pd.read_csv('zhdf_mid.csv')
zvt1 = pd.read_csv('zvt1.csv')
zvt2 = pd.read_csv('zvt2.csv')
zvt3 = pd.read_csv('zvt3.csv')
zvt4 = pd.read_csv('zvt4.csv')
zvt5 = pd.read_csv('zvt5.csv')

# %%
print("cut_price_shares")
cut_price_shares.info()
print("days_to_pending")
days_to_pending.info()
print("market_heat")
market_heat.info()
print("price_cut")
price_cut.info()
print("sales_to_list")
sales_to_list.info()
print("sales_values")
sales_values.info()
print("zhdf_bot")
zhdf_bot.info()
print("zhdf_top")
zhdf_top.info()
print("zhdf_mid")
zhdf_mid.info()
print("zvt1")
zvt1.info()
print("zvt2")
zvt2.info()
print("zvt3")
zvt3.info()
print("zvt4")
zvt4.info()
print("zvt5")
zvt5.info()
# Out:
# cut_price_shares
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Columns: 927 entries, Unnamed: 0 to Lamesa, TX
# dtypes: float64(926), object(1)
# memory usage: 550.5+ KB
# days_to_pending
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Columns: 767 entries, Unnamed: 0 to Craig, CO
# dtypes: float64(766), object(1)
# memory usage: 455.5+ KB
# market_heat
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Columns: 929 entries, Unnamed: 0 to Lamesa, TX
# dtypes: float64(928), object(1)
# memory usage: 551.7+ KB
# price_cut
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Columns: 703 entries, Unnamed: 0 to Ruidoso, NM
# dtypes: float64(702), object(1)
# memory usage: 417.5+ KB
# sales_to_list
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 50 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  75 non-null     object
#  1   AL          75 non-null     float64
#  2   AR          75 non-null     float64
#  3   AZ          75 non-null     float64
#  4   CA          75 non-null     float64
#  5   CO          75 non-null     float64
#  6   CT          75 non-null     float64
#  7   DE          75 non-null     float64
#  8   FL          75 non-null     float64
#  9   GA          75 non-null     float64
#  10  HI          75 non-null     float64
#  11  IA          75 non-null     float64
#  12  ID          37 non-null     float64
#  13  IL          75 non-null     float64
#  14  IN          75 non-null     float64
#  15  KS          30 non-null     float64
#  16  KY          75 non-null     float64
#  17  LA          75 non-null     float64
#  18  MA          75 non-null     float64
#  19  MD          75 non-null     float64
#  20  ME          75 non-null     float64
#  21  MI          75 non-null     float64
#  22  MN          75 non-null     float64
#  23  MO          75 non-null     float64
#  24  MS          75 non-null     float64
#  25  MT          75 non-null     float64
#  26  NC          75 non-null     float64
#  27  ND          37 non-null     float64
#  28  NE          75 non-null     float64
#  29  NH          75 non-null     float64
#  30  NJ          75 non-null     float64
#  31  NM          75 non-null     float64
#  32  NV          75 non-null     float64
#  33  NY          75 non-null     float64
#  34  OH          75 non-null     float64
#  35  OK          75 non-null     float64
#  36  OR          75 non-null     float64
#  37  PA          75 non-null     float64
#  38  RI          75 non-null     float64
#  39  SC          75 non-null     float64
#  40  SD          75 non-null     float64
#  41  TN          75 non-null     float64
#  42  TX          75 non-null     float64
#  43  UT          75 non-null     float64
#  44  VA          75 non-null     float64
#  45  VT          61 non-null     float64
#  46  WA          75 non-null     float64
#  47  WI          75 non-null     float64
#  48  WV          75 non-null     float64
#  49  WY          75 non-null     float64
# dtypes: float64(49), object(1)
# memory usage: 29.4+ KB
# sales_values
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Columns: 703 entries, Unnamed: 0 to Spirit Lake, IA
# dtypes: float64(702), object(1)
# memory usage: 1.0+ MB
# zhdf_bot
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Columns: 893 entries, Unnamed: 0 to Lamesa, TX
# dtypes: float64(892), object(1)
# memory usage: 2.0+ MB
# zhdf_top
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Columns: 896 entries, Unnamed: 0 to Lamesa, TX
# dtypes: float64(895), object(1)
# memory usage: 2.0+ MB
# zhdf_mid
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Columns: 896 entries, Unnamed: 0 to Lamesa, TX
# dtypes: float64(895), object(1)
# memory usage: 2.0+ MB
# zvt1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Columns: 672 entries, Unnamed: 0 to Ketchikan, AK
# dtypes: float64(671), object(1)
# memory usage: 1.5+ MB
# zvt2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Columns: 852 entries, Unnamed: 0 to Craig, CO
# dtypes: float64(851), object(1)
# memory usage: 1.9+ MB
# zvt3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Columns: 885 entries, Unnamed: 0 to Craig, CO
# dtypes: float64(884), object(1)
# memory usage: 2.0+ MB
# zvt4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Columns: 856 entries, Unnamed: 0 to Craig, CO
# dtypes: float64(855), object(1)
# memory usage: 1.9+ MB
# zvt5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Columns: 759 entries, Unnamed: 0 to Craig, CO
# dtypes: float64(758), object(1)
# memory usage: 1.7+ MB

# %%
all_cities = [set(cut_price_shares.columns), set(days_to_pending.columns), set(market_heat.columns),\
              set(price_cut.columns), set(sales_values.columns), set(zhdf_bot.columns), set(zhdf_mid.columns),\
              set(zhdf_top.columns), set(zvt1.columns), set(zvt2.columns), set(zvt3.columns), set(zvt4.columns), set(zvt5.columns)]

# %%
common_cities = list(set.intersection(*all_cities))
common_cities.remove('Unnamed: 0')

# %%
len(common_cities)
# Out:
# 509

# %%
sorted(common_cities)
# Out:
# ['Aberdeen, WA',
#  'Abilene, TX',
#  'Adrian, MI',
#  'Akron, OH',
#  'Albany, NY',
#  'Albany, OR',
#  'Albemarle, NC',
#  'Albuquerque, NM',
#  'Alexandria, LA',
#  'Allentown, PA',
#  'Amarillo, TX',
#  'Ames, IA',
#  'Angola, IN',
#  'Ann Arbor, MI',
#  'Anniston, AL',
#  'Appleton, WI',
#  'Ardmore, OK',
#  'Asheville, NC',
#  'Ashland, OH',
#  'Ashtabula, OH',
#  'Astoria, OR',
#  'Athens, GA',
#  'Athens, TX',
#  'Atlanta, GA',
#  'Atlantic City, NJ',
#  'Auburn, AL',
#  'Augusta, GA',
#  'Augusta, ME',
#  'Austin, TX',
#  'Bakersfield, CA',
#  'Baltimore, MD',
#  'Bangor, ME',
#  'Baraboo, WI',
#  'Barnstable Town, MA',
#  'Bartlesville, OK',
#  'Baton Rouge, LA',
#  'Battle Creek, MI',
#  'Bay City, MI',
#  'Beaumont, TX',
#  'Beckley, WV',
#  'Bellefontaine, OH',
#  'Bellingham, WA',
#  'Bemidji, MN',
#  'Bend, OR',
#  'Big Rapids, MI',
#  'Big Stone Gap, VA',
#  'Billings, MT',
#  'Binghamton, NY',
#  'Birmingham, AL',
#  'Bismarck, ND',
#  'Blacksburg, VA',
#  'Bloomington, IL',
#  'Bloomington, IN',
#  'Bloomsburg, PA',
#  'Boise City, ID',
#  'Boone, NC',
#  'Boston, MA',
#  'Boulder, CO',
#  'Bowling Green, KY',
#  'Bozeman, MT',
#  'Brainerd, MN',
#  'Branson, MO',
#  'Breckenridge, CO',
#  'Bremerton, WA',
#  'Brenham, TX',
#  'Bridgeport, CT',
#  'Brownsville, TX',
#  'Brownwood, TX',
#  'Brunswick, GA',
#  'Buffalo, NY',
#  'Burlington, IA',
#  'Burlington, NC',
#  'Burlington, VT',
#  'Ca-¦on City, CO',
#  'Cadillac, MI',
#  'Calhoun, GA',
#  'California, MD',
#  'Canton, OH',
#  'Cape Coral, FL',
#  'Cape Girardeau, MO',
#  'Carson City, NV',
#  'Cedar Rapids, IA',
#  'Cedartown, GA',
#  'Centralia, WA',
#  'Chambersburg, PA',
#  'Champaign, IL',
#  'Charleston, SC',
#  'Charleston, WV',
#  'Charlotte, NC',
#  'Charlottesville, VA',
#  'Chattanooga, TN',
#  'Chicago, IL',
#  'Chico, CA',
#  'Chillicothe, OH',
#  'Cincinnati, OH',
#  'Clarksburg, WV',
#  'Clarksville, TN',
#  'Clearlake, CA',
#  'Cleveland, OH',
#  'Cleveland, TN',
#  'Clewiston, FL',
#  'Clinton, IA',
#  "Coeur d'Alene, ID",
#  'College Station, TX',
#  'Colorado Springs, CO',
#  'Columbia, MO',
#  'Columbia, SC',
#  'Columbus, GA',
#  'Columbus, IN',
#  'Columbus, OH',
#  'Concord, NH',
#  'Cookeville, TN',
#  'Coos Bay, OR',
#  'Cornelia, GA',
#  'Corning, NY',
#  'Corpus Christi, TX',
#  'Corvallis, OR',
#  'Crawfordsville, IN',
#  'Crestview, FL',
#  'Crossville, TN',
#  'Cullowhee, NC',
#  'Cumberland, MD',
#  'Dallas, TX',
#  'Danville, KY',
#  'Danville, VA',
#  'Daphne, AL',
#  'Davenport, IA',
#  'Decatur, IL',
#  'Deltona, FL',
#  'Denver, CO',
#  'Des Moines, IA',
#  'Detroit, MI',
#  'Dover, DE',
#  'Dubuque, IA',
#  'Duluth, MN',
#  'Duncan, OK',
#  'Durango, CO',
#  'Durant, OK',
#  'Durham, NC',
#  'East Stroudsburg, PA',
#  'Eau Claire, WI',
#  'Edwards, CO',
#  'El Paso, TX',
#  'Elizabeth City, NC',
#  'Elizabethtown, KY',
#  'Elkhart, IN',
#  'Elko, NV',
#  'Ellensburg, WA',
#  'Enid, OK',
#  'Erie, PA',
#  'Eugene, OR',
#  'Evansville, IN',
#  'Fairmont, WV',
#  'Farmington, MO',
#  'Farmington, NM',
#  'Fayetteville, AR',
#  'Fayetteville, NC',
#  'Fergus Falls, MN',
#  'Fernley, NV',
#  'Findlay, OH',
#  'Flagstaff, AZ',
#  'Flint, MI',
#  'Florence, SC',
#  'Fond du Lac, WI',
#  'Forest City, NC',
#  'Fort Collins, CO',
#  'Fort Madison, IA',
#  'Fort Smith, AR',
#  'Fort Wayne, IN',
#  'Frankfort, KY',
#  'Freeport, IL',
#  'Fremont, NE',
#  'Fresno, CA',
#  'Gainesville, FL',
#  'Gainesville, GA',
#  'Gardnerville Ranchos, NV',
#  'Georgetown, SC',
#  'Gettysburg, PA',
#  'Glasgow, KY',
#  'Glens Falls, NY',
#  'Glenwood Springs, CO',
#  'Gloversville, NY',
#  'Goldsboro, NC',
#  'Grand Forks, ND',
#  'Grand Island, NE',
#  'Grand Junction, CO',
#  'Grand Rapids, MI',
#  'Grants Pass, OR',
#  'Greeley, CO',
#  'Green Bay, WI',
#  'Greensboro, NC',
#  'Greenville, NC',
#  'Greenville, OH',
#  'Greenville, SC',
#  'Greenwood, SC',
#  'Gulfport, MS',
#  'Hagerstown, MD',
#  'Harrisburg, PA',
#  'Harrisonburg, VA',
#  'Hartford, CT',
#  'Hattiesburg, MS',
#  'Hermiston, OR',
#  'Hickory, NC',
#  'Hillsdale, MI',
#  'Hilo, HI',
#  'Hilton Head Island, SC',
#  'Hinesville, GA',
#  'Holland, MI',
#  'Homosassa Springs, FL',
#  'Hot Springs, AR',
#  'Houston, TX',
#  'Hudson, NY',
#  'Huntington, WV',
#  'Huntsville, AL',
#  'Huntsville, TX',
#  'Idaho Falls, ID',
#  'Indiana, PA',
#  'Indianapolis, IN',
#  'Iowa City, IA',
#  'Jackson, MI',
#  'Jackson, MS',
#  'Jacksonville, FL',
#  'Jacksonville, NC',
#  'Jamestown, NY',
#  'Janesville, WI',
#  'Jasper, IN',
#  'Jefferson City, MO',
#  'Johnson City, TN',
#  'Joplin, MO',
#  'Kahului, HI',
#  'Kalamazoo, MI',
#  'Kankakee, IL',
#  'Kansas City, MO',
#  'Kapaa, HI',
#  'Kendallville, IN',
#  'Kennewick, WA',
#  'Kerrville, TX',
#  'Key West, FL',
#  'Kill Devil Hills, NC',
#  'Killeen, TX',
#  'Kingsport, TN',
#  'Kingston, NY',
#  'Kinston, NC',
#  'Klamath Falls, OR',
#  'Knoxville, TN',
#  'Kokomo, IN',
#  'La Crosse, WI',
#  'LaGrange, GA',
#  'Lafayette, IN',
#  'Lafayette, LA',
#  'Lake City, FL',
#  'Lake Havasu City, AZ',
#  'Lakeland, FL',
#  'Lancaster, PA',
#  'Lansing, MI',
#  'Las Cruces, NM',
#  'Las Vegas, NV',
#  'Lawrence, KS',
#  'Lawton, OK',
#  'Lewiston, ID',
#  'Lexington, KY',
#  'Lima, OH',
#  'Lincoln, NE',
#  'Little Rock, AR',
#  'Logan, UT',
#  'London, KY',
#  'Longview, TX',
#  'Longview, WA',
#  'Los Angeles, CA',
#  'Louisville, KY',
#  'Lubbock, TX',
#  'Lumberton, NC',
#  'Lynchburg, VA',
#  'Macon, GA',
#  'Madera, CA',
#  'Madison, WI',
#  'Manchester, NH',
#  'Manhattan, KS',
#  'Mankato, MN',
#  'Mansfield, OH',
#  'Marietta, OH',
#  'Marion, IN',
#  'Marion, OH',
#  'Marquette, MI',
#  'Mason City, IA',
#  'McAlester, OK',
#  'McAllen, TX',
#  'Medford, OR',
#  'Memphis, TN',
#  'Merced, CA',
#  'Miami, FL',
#  'Miami, OK',
#  'Michigan City, IN',
#  'Midland, MI',
#  'Milledgeville, GA',
#  'Milwaukee, WI',
#  'Minneapolis, MN',
#  'Mobile, AL',
#  'Modesto, CA',
#  'Monroe, LA',
#  'Monroe, MI',
#  'Montgomery, AL',
#  'Montrose, CO',
#  'Morehead City, NC',
#  'Morgantown, WV',
#  'Moses Lake, WA',
#  'Mount Airy, NC',
#  'Mount Pleasant, MI',
#  'Mount Sterling, KY',
#  'Mount Vernon, OH',
#  'Mount Vernon, WA',
#  'Muncie, IN',
#  'Muscatine, IA',
#  'Muskegon, MI',
#  'Muskogee, OK',
#  'Myrtle Beach, SC',
#  'Napa, CA',
#  'Naples, FL',
#  'Nashville, TN',
#  'New Bern, NC',
#  'New Castle, IN',
#  'New Castle, PA',
#  'New Haven, CT',
#  'New Orleans, LA',
#  'New Philadelphia, OH',
#  'New York, NY',
#  'Newport, OR',
#  'Niles, MI',
#  'Nogales, AZ',
#  'Norfolk, NE',
#  'North Platte, NE',
#  'North Port, FL',
#  'North Wilkesboro, NC',
#  'Norwich, CT',
#  'Oak Harbor, WA',
#  'Ocala, FL',
#  'Ocean City, NJ',
#  'Ogden, UT',
#  'Oil City, PA',
#  'Okeechobee, FL',
#  'Oklahoma City, OK',
#  'Olean, NY',
#  'Olympia, WA',
#  'Omaha, NE',
#  'Oneonta, NY',
#  'Ontario, OR',
#  'Orlando, FL',
#  'Oshkosh, WI',
#  'Oxnard, CA',
#  'Paducah, KY',
#  'Palatka, FL',
#  'Palm Bay, FL',
#  'Panama City, FL',
#  'Parkersburg, WV',
#  'Payson, AZ',
#  'Pensacola, FL',
#  'Peoria, IL',
#  'Philadelphia, PA',
#  'Phoenix, AZ',
#  'Pinehurst, NC',
#  'Pittsburgh, PA',
#  'Pittsfield, MA',
#  'Plattsburgh, NY',
#  'Plymouth, IN',
#  'Pocatello, ID',
#  'Ponca City, OK',
#  'Port Angeles, WA',
#  'Port St. Lucie, FL',
#  'Portland, ME',
#  'Portland, OR',
#  'Pottsville, PA',
#  'Prineville, OR',
#  'Providence, RI',
#  'Provo, UT',
#  'Pueblo, CO',
#  'Punta Gorda, FL',
#  'Quincy, IL',
#  'Racine, WI',
#  'Raleigh, NC',
#  'Rapid City, SD',
#  'Reading, PA',
#  'Red Bluff, CA',
#  'Red Wing, MN',
#  'Redding, CA',
#  'Reno, NV',
#  'Rexburg, ID',
#  'Richmond, KY',
#  'Richmond, VA',
#  'Riverside, CA',
#  'Roanoke, VA',
#  'Rochelle, IL',
#  'Rochester, MN',
#  'Rochester, NY',
#  'Rockford, IL',
#  'Rocky Mount, NC',
#  'Rolla, MO',
#  'Rome, GA',
#  'Roseburg, OR',
#  'Rutland, VT',
#  'Sacramento, CA',
#  'Saginaw, MI',
#  'Salem, OH',
#  'Salem, OR',
#  'Salina, KS',
#  'Salinas, CA',
#  'Salisbury, MD',
#  'Salt Lake City, UT',
#  'San Antonio, TX',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'San Jose, CA',
#  'San Luis Obispo, CA',
#  'Sandusky, OH',
#  'Sanford, NC',
#  'Santa Cruz, CA',
#  'Santa Fe, NM',
#  'Santa Maria, CA',
#  'Santa Rosa, CA',
#  'Savannah, GA',
#  'Scottsbluff, NE',
#  'Scranton, PA',
#  'Seattle, WA',
#  'Sebastian, FL',
#  'Sebring, FL',
#  'Seneca, SC',
#  'Sevierville, TN',
#  'Shawnee, OK',
#  'Sheboygan, WI',
#  'Shelton, WA',
#  'Sherman, TX',
#  'Show Low, AZ',
#  'Shreveport, LA',
#  'Sidney, OH',
#  'Sierra Vista, AZ',
#  'Sioux City, IA',
#  'Somerset, PA',
#  'Sonora, CA',
#  'South Bend, IN',
#  'Spartanburg, SC',
#  'Spokane, WA',
#  'Springfield, MA',
#  'Springfield, MO',
#  'Springfield, OH',
#  'St. Cloud, MN',
#  'St. George, UT',
#  'St. Joseph, MO',
#  'St. Louis, MO',
#  'St. Marys, GA',
#  'State College, PA',
#  'Statesboro, GA',
#  'Staunton, VA',
#  'Sterling, IL',
#  'Stillwater, OK',
#  'Stockton, CA',
#  'Sturgis, MI',
#  'Sumter, SC',
#  'Syracuse, NY',
#  'Tahlequah, OK',
#  'Tallahassee, FL',
#  'Tampa, FL',
#  'Terre Haute, IN',
#  'The Villages, FL',
#  'Toccoa, GA',
#  'Toledo, OH',
#  'Topeka, KS',
#  'Torrington, CT',
#  'Traverse City, MI',
#  'Trenton, NJ',
#  'Truckee, CA',
#  'Tucson, AZ',
#  'Tulsa, OK',
#  'Tuscaloosa, AL',
#  'Twin Falls, ID',
#  'Tyler, TX',
#  'United States',
#  'Urban Honolulu, HI',
#  'Utica, NY',
#  'Valdosta, GA',
#  'Vallejo, CA',
#  'Victoria, TX',
#  'Vineland, NJ',
#  'Virginia Beach, VA',
#  'Visalia, CA',
#  'Waco, TX',
#  'Walla Walla, WA',
#  'Warner Robins, GA',
#  'Warsaw, IN',
#  'Washington, DC',
#  'Waterloo, IA',
#  'Watertown, NY',
#  'Wausau, WI',
#  'Weirton, WV',
#  'Wenatchee, WA',
#  'Wheeling, WV',
#  'Whitewater, WI',
#  'Wichita Falls, TX',
#  'Wichita, KS',
#  'Williamsport, PA',
#  'Wilmington, NC',
#  'Wilson, NC',
#  'Winchester, VA',
#  'Winston, NC',
#  'Worcester, MA',
#  'Yakima, WA',
#  'York, PA',
#  'Youngstown, OH',
#  'Yuba City, CA',
#  'Yuma, AZ',
#  'Zanesville, OH']

# %%
def filter_city_columns(df):
  df.rename(columns={'Unnamed: 0': 'date'}, inplace=True)
  df['date'] = pd.to_datetime(df['date'], format='mixed')
  df.set_index('date', inplace=True)

  df = df[df.columns.intersection(common_cities)]

  missed = []

  for city in common_cities:
    if city not in df.columns:
      missed.append(city)

  if len(missed) > 0:
    print(f"Missing the following cities: ", str(missed))

  else:
    print("All cities matching!")

  return df

# %%
 cut_price_shares = filter_city_columns(cut_price_shares)
 days_to_pending = filter_city_columns(days_to_pending)
 market_heat = filter_city_columns(market_heat)
 price_cut = filter_city_columns(price_cut)
 sales_values = filter_city_columns(sales_values)
 zhdf_bot = filter_city_columns(zhdf_bot)
 zhdf_top = filter_city_columns(zhdf_top)
 zhdf_mid = filter_city_columns(zhdf_mid)
 zvt1 = filter_city_columns(zvt1)
 zvt2 = filter_city_columns(zvt2)
 zvt3 = filter_city_columns(zvt3)
 zvt4 = filter_city_columns(zvt4)
 zvt5 = filter_city_columns(zvt5)
# Out:
# All cities matching!
# All cities matching!
# All cities matching!
# All cities matching!
# All cities matching!
# All cities matching!
# All cities matching!
# All cities matching!
# All cities matching!
# All cities matching!
# All cities matching!
# All cities matching!
# All cities matching!

# %%
sales_values
# Out:
#             United States  New York, NY  Los Angeles, CA  Chicago, IL  \
# date
# 2008-02-29       172500.0      399900.0         470000.0     218000.0
# 2008-03-31       177500.0      390000.0         455000.0     221575.0
# 2008-04-30       179000.0      390390.0         458000.0     221796.0
# 2008-05-31       180000.0      395000.0         440000.0     228000.0
# 2008-06-30       185000.0      400000.0         435000.0     235000.0
# ...                   ...           ...              ...          ...
# 2023-11-30       325000.0      565000.0         900000.0     285000.0
# 2023-12-31       322500.0      561000.0         870750.0     280000.0
# 2024-01-31       325000.0      565000.0         865000.0     280000.0
# 2024-02-29       335000.0      557500.0         915500.0     285000.0
# 2024-03-31       345511.0      570000.0         920000.0     305000.0
#
#             Dallas, TX  Houston, TX  Washington, DC  Philadelphia, PA  \
# date
# 2008-02-29    138000.0     145100.0        338000.0          191000.0
# 2008-03-31    145900.0     145000.0        327250.0          198900.0
# 2008-04-30    144900.0     146000.0        330000.0          200000.0
# 2008-05-31    150000.0     150000.0        335000.0          212000.0
# 2008-06-30    155500.0     156000.0        335000.0          218000.0
# ...                ...          ...             ...               ...
# 2023-11-30    373000.0     315000.0        499000.0          315000.0
# 2023-12-31    367372.0     310000.0        490000.0          311000.0
# 2024-01-31    367350.0     307000.0        470000.0          300000.0
# 2024-02-29    380000.0     325000.0        510000.0          300000.0
# 2024-03-31    390000.0     322311.0        539000.0          315000.0
#
#             Miami, FL  Atlanta, GA  ...  Scottsbluff, NE  Fremont, NE  \
# date                                ...
# 2008-02-29   239000.0     150000.0  ...              NaN          NaN
# 2008-03-31   235000.0     154500.0  ...              NaN          NaN
# 2008-04-30   238000.0     154700.0  ...              NaN          NaN
# 2008-05-31   232000.0     158950.0  ...              NaN          NaN
# 2008-06-30   237600.0     158800.0  ...              NaN          NaN
# ...               ...          ...  ...              ...          ...
# 2023-11-30   432000.0     345000.0  ...              NaN     201000.0
# 2023-12-31   440000.0     336000.0  ...              NaN     216250.0
# 2024-01-31   435000.0     330000.0  ...              NaN     182500.0
# 2024-02-29   465000.0     355000.0  ...              NaN     225000.0
# 2024-03-31   482500.0     365000.0  ...         174000.0     215000.0
#
#             Kill Devil Hills, NC  North Platte, NE  Brenham, TX  Angola, IN  \
# date
# 2008-02-29              297500.0               NaN          NaN         NaN
# 2008-03-31              305000.0               NaN          NaN         NaN
# 2008-04-30              320000.0               NaN          NaN         NaN
# 2008-05-31              325000.0               NaN          NaN         NaN
# 2008-06-30              308500.0               NaN          NaN         NaN
# ...                          ...               ...          ...         ...
# 2023-11-30              570000.0          140000.0          NaN    289000.0
# 2023-12-31              680000.0          195500.0          NaN    221796.0
# 2024-01-31              600000.0          165000.0          NaN    205547.0
# 2024-02-29              605250.0          177000.0          NaN    205497.0
# 2024-03-31              580000.0          187500.0     291800.0    230000.0
#
#             Breckenridge, CO  Miami, OK  Toccoa, GA  Prineville, OR
# date
# 2008-02-29          395000.0        NaN         NaN             NaN
# 2008-03-31          454000.0        NaN         NaN             NaN
# 2008-04-30          445000.0        NaN         NaN             NaN
# 2008-05-31          420000.0        NaN         NaN             NaN
# 2008-06-30          448700.0        NaN         NaN             NaN
# ...                      ...        ...         ...             ...
# 2023-11-30         1005000.0        NaN    198000.0             NaN
# 2023-12-31         1012500.0        NaN    170000.0             NaN
# 2024-01-31          740000.0        NaN    165000.0             NaN
# 2024-02-29          887457.0        NaN    173250.0             NaN
# 2024-03-31          985000.0   129500.0    210000.0        413500.0
#
# [194 rows x 509 columns]

# %%
def save_city_metrics(idx):

  df = sales_values.iloc[-75:, idx]

  df = pd.concat([df, cut_price_shares.iloc[:,idx]], axis=1)
  df = pd.concat([df, days_to_pending.iloc[:,idx]], axis=1)
  df = pd.concat([df, market_heat.iloc[:,idx]], axis=1)
  df = pd.concat([df, price_cut.iloc[:,idx]], axis=1)

  df = pd.concat([df, zhdf_bot.iloc[-76:,idx]], axis=1)
  df = pd.concat([df, zhdf_mid.iloc[-76:,idx]], axis=1)
  df = pd.concat([df, zhdf_top.iloc[-76:,idx]], axis=1)
  df = pd.concat([df, zvt1.iloc[-77:,idx]], axis=1)
  df = pd.concat([df, zvt2.iloc[-77:,idx]], axis=1)
  df = pd.concat([df, zvt3.iloc[-77:,idx]], axis=1)
  df = pd.concat([df, zvt4.iloc[-77:,idx]], axis=1)
  df = pd.concat([df, zvt5.iloc[-77:,idx]], axis=1)


  column_names = ['sales_values','cut_price_shares','days_to_pending','market_heat','price_cut', 'zhdf_bot', 'zhdf_mid', 'zhdf_top', 'zvt1', 'zvt2', 'zvt3', 'zvt4', 'zvt5']
  df.columns = column_names

  city_name = cut_price_shares.columns[idx].replace(", ", "-").replace(" ", "").replace(".","").replace('-¦', 'n').lower()
  df.to_csv(f'city_metrics_2/{city_name}_metrics.csv', index=True)
  print(f'Saved {city_name} metrics')
  return df

# %%
for i in range(len(common_cities)):
  df = save_city_metrics(i)
# Out:
# Saved unitedstates metrics
# Saved newyork-ny metrics
# Saved losangeles-ca metrics
# Saved chicago-il metrics
# Saved dallas-tx metrics
# Saved houston-tx metrics
# Saved washington-dc metrics
# Saved philadelphia-pa metrics
# Saved miami-fl metrics
# Saved atlanta-ga metrics
# Saved boston-ma metrics
# Saved phoenix-az metrics
# Saved sanfrancisco-ca metrics
# Saved riverside-ca metrics
# Saved detroit-mi metrics
# Saved seattle-wa metrics
# Saved minneapolis-mn metrics
# Saved sandiego-ca metrics
# Saved tampa-fl metrics
# Saved denver-co metrics
# Saved baltimore-md metrics
# Saved stlouis-mo metrics
# Saved orlando-fl metrics
# Saved charlotte-nc metrics
# Saved sanantonio-tx metrics
# Saved portland-or metrics
# Saved sacramento-ca metrics
# Saved pittsburgh-pa metrics
# Saved cincinnati-oh metrics
# Saved austin-tx metrics
# Saved lasvegas-nv metrics
# Saved kansascity-mo metrics
# Saved columbus-oh metrics
# Saved indianapolis-in metrics
# Saved cleveland-oh metrics
# Saved sanjose-ca metrics
# Saved nashville-tn metrics
# Saved virginiabeach-va metrics
# Saved providence-ri metrics
# Saved jacksonville-fl metrics
# Saved milwaukee-wi metrics
# Saved oklahomacity-ok metrics
# Saved raleigh-nc metrics
# Saved memphis-tn metrics
# Saved richmond-va metrics
# Saved louisville-ky metrics
# Saved neworleans-la metrics
# Saved saltlakecity-ut metrics
# Saved hartford-ct metrics
# Saved buffalo-ny metrics
# Saved birmingham-al metrics
# Saved rochester-ny metrics
# Saved grandrapids-mi metrics
# Saved tucson-az metrics
# Saved urbanhonolulu-hi metrics
# Saved tulsa-ok metrics
# Saved fresno-ca metrics
# Saved worcester-ma metrics
# Saved omaha-ne metrics
# Saved bridgeport-ct metrics
# Saved greenville-sc metrics
# Saved albuquerque-nm metrics
# Saved bakersfield-ca metrics
# Saved albany-ny metrics
# Saved knoxville-tn metrics
# Saved batonrouge-la metrics
# Saved mcallen-tx metrics
# Saved newhaven-ct metrics
# Saved elpaso-tx metrics
# Saved allentown-pa metrics
# Saved oxnard-ca metrics
# Saved columbia-sc metrics
# Saved northport-fl metrics
# Saved charleston-sc metrics
# Saved greensboro-nc metrics
# Saved stockton-ca metrics
# Saved capecoral-fl metrics
# Saved boisecity-id metrics
# Saved coloradosprings-co metrics
# Saved littlerock-ar metrics
# Saved lakeland-fl metrics
# Saved akron-oh metrics
# Saved desmoines-ia metrics
# Saved springfield-ma metrics
# Saved ogden-ut metrics
# Saved madison-wi metrics
# Saved winston-nc metrics
# Saved deltona-fl metrics
# Saved syracuse-ny metrics
# Saved provo-ut metrics
# Saved toledo-oh metrics
# Saved wichita-ks metrics
# Saved durham-nc metrics
# Saved augusta-ga metrics
# Saved palmbay-fl metrics
# Saved jackson-ms metrics
# Saved harrisburg-pa metrics
# Saved spokane-wa metrics
# Saved scranton-pa metrics
# Saved chattanooga-tn metrics
# Saved modesto-ca metrics
# Saved lancaster-pa metrics
# Saved portland-me metrics
# Saved youngstown-oh metrics
# Saved lansing-mi metrics
# Saved fayetteville-ar metrics
# Saved fayetteville-nc metrics
# Saved lexington-ky metrics
# Saved pensacola-fl metrics
# Saved santarosa-ca metrics
# Saved reno-nv metrics
# Saved huntsville-al metrics
# Saved portstlucie-fl metrics
# Saved lafayette-la metrics
# Saved myrtlebeach-sc metrics
# Saved springfield-mo metrics
# Saved visalia-ca metrics
# Saved killeen-tx metrics
# Saved asheville-nc metrics
# Saved york-pa metrics
# Saved vallejo-ca metrics
# Saved santamaria-ca metrics
# Saved salinas-ca metrics
# Saved salem-or metrics
# Saved mobile-al metrics
# Saved reading-pa metrics
# Saved corpuschristi-tx metrics
# Saved brownsville-tx metrics
# Saved manchester-nh metrics
# Saved fortwayne-in metrics
# Saved gulfport-ms metrics
# Saved salisbury-md metrics
# Saved flint-mi metrics
# Saved peoria-il metrics
# Saved canton-oh metrics
# Saved savannah-ga metrics
# Saved beaumont-tx metrics
# Saved shreveport-la metrics
# Saved trenton-nj metrics
# Saved montgomery-al metrics
# Saved davenport-ia metrics
# Saved tallahassee-fl metrics
# Saved eugene-or metrics
# Saved naples-fl metrics
# Saved annarbor-mi metrics
# Saved ocala-fl metrics
# Saved hickory-nc metrics
# Saved huntington-wv metrics
# Saved fortcollins-co metrics
# Saved rockford-il metrics
# Saved lincoln-ne metrics
# Saved gainesville-fl metrics
# Saved boulder-co metrics
# Saved greenbay-wi metrics
# Saved columbus-ga metrics
# Saved southbend-in metrics
# Saved spartanburg-sc metrics
# Saved greeley-co metrics
# Saved lubbock-tx metrics
# Saved clarksville-tn metrics
# Saved roanoke-va metrics
# Saved evansville-in metrics
# Saved kingsport-tn metrics
# Saved kennewick-wa metrics
# Saved utica-ny metrics
# Saved hagerstown-md metrics
# Saved duluth-mn metrics
# Saved olympia-wa metrics
# Saved longview-tx metrics
# Saved wilmington-nc metrics
# Saved sanluisobispo-ca metrics
# Saved crestview-fl metrics
# Saved merced-ca metrics
# Saved waco-tx metrics
# Saved cedarrapids-ia metrics
# Saved atlanticcity-nj metrics
# Saved bremerton-wa metrics
# Saved santacruz-ca metrics
# Saved erie-pa metrics
# Saved norwich-ct metrics
# Saved amarillo-tx metrics
# Saved tuscaloosa-al metrics
# Saved collegestation-tx metrics
# Saved kalamazoo-mi metrics
# Saved lynchburg-va metrics
# Saved charleston-wv metrics
# Saved yakima-wa metrics
# Saved binghamton-ny metrics
# Saved fortsmith-ar metrics
# Saved appleton-wi metrics
# Saved topeka-ks metrics
# Saved macon-ga metrics
# Saved tyler-tx metrics
# Saved barnstabletown-ma metrics
# Saved daphne-al metrics
# Saved bellingham-wa metrics
# Saved burlington-vt metrics
# Saved rochester-mn metrics
# Saved lafayette-in metrics
# Saved champaign-il metrics
# Saved medford-or metrics
# Saved charlottesville-va metrics
# Saved lascruces-nm metrics
# Saved chico-ca metrics
# Saved hiltonheadisland-sc metrics
# Saved athens-ga metrics
# Saved lakehavasucity-az metrics
# Saved columbia-mo metrics
# Saved monroe-la metrics
# Saved elkhart-in metrics
# Saved johnsoncity-tn metrics
# Saved yuma-az metrics
# Saved gainesville-ga metrics
# Saved jacksonville-nc metrics
# Saved florence-sc metrics
# Saved hilo-hi metrics
# Saved stcloud-mn metrics
# Saved racine-wi metrics
# Saved bend-or metrics
# Saved saginaw-mi metrics
# Saved warnerrobins-ga metrics
# Saved terrehaute-in metrics
# Saved torrington-ct metrics
# Saved puntagorda-fl metrics
# Saved billings-mt metrics
# Saved redding-ca metrics
# Saved kingston-ny metrics
# Saved panamacity-fl metrics
# Saved joplin-mo metrics
# Saved dover-de metrics
# Saved yubacity-ca metrics
# Saved bowlinggreen-ky metrics
# Saved stgeorge-ut metrics
# Saved muskegon-mi metrics
# Saved abilene-tx metrics
# Saved iowacity-ia metrics
# Saved auburn-al metrics
# Saved bloomington-il metrics
# Saved hattiesburg-ms metrics
# Saved oshkosh-wi metrics
# Saved eauclaire-wi metrics
# Saved greenville-nc metrics
# Saved burlington-nc metrics
# Saved waterloo-ia metrics
# Saved coeurd'alene-id metrics
# Saved eaststroudsburg-pa metrics
# Saved pueblo-co metrics
# Saved blacksburg-va metrics
# Saved wausau-wi metrics
# Saved kahului-hi metrics
# Saved janesville-wi metrics
# Saved bloomington-in metrics
# Saved jackson-mi metrics
# Saved statecollege-pa metrics
# Saved sebastian-fl metrics
# Saved madera-ca metrics
# Saved chambersburg-pa metrics
# Saved vineland-nj metrics
# Saved idahofalls-id metrics
# Saved grandjunction-co metrics
# Saved elizabethtown-ky metrics
# Saved niles-mi metrics
# Saved monroe-mi metrics
# Saved santafe-nm metrics
# Saved concord-nh metrics
# Saved alexandria-la metrics
# Saved traversecity-mi metrics
# Saved bangor-me metrics
# Saved homosassasprings-fl metrics
# Saved jeffersoncity-mo metrics
# Saved london-ky metrics
# Saved siouxcity-ia metrics
# Saved wichitafalls-tx metrics
# Saved valdosta-ga metrics
# Saved logan-ut metrics
# Saved flagstaff-az metrics
# Saved rockymount-nc metrics
# Saved pottsville-pa metrics
# Saved winchester-va metrics
# Saved wheeling-wv metrics
# Saved morgantown-wv metrics
# Saved lacrosse-wi metrics
# Saved napa-ca metrics
# Saved rapidcity-sd metrics
# Saved sumter-sc metrics
# Saved springfield-oh metrics
# Saved harrisonburg-va metrics
# Saved battlecreek-mi metrics
# Saved sherman-tx metrics
# Saved manhattan-ks metrics
# Saved bismarck-nd metrics
# Saved pittsfield-ma metrics
# Saved mountvernon-wa metrics
# Saved jamestown-ny metrics
# Saved thevillages-fl metrics
# Saved albany-or metrics
# Saved glensfalls-ny metrics
# Saved lawton-ok metrics
# Saved cleveland-tn metrics
# Saved sierravista-az metrics
# Saved ames-ia metrics
# Saved mansfield-oh metrics
# Saved staunton-va metrics
# Saved augusta-me metrics
# Saved newbern-nc metrics
# Saved farmington-nm metrics
# Saved stjoseph-mo metrics
# Saved wenatchee-wa metrics
# Saved holland-mi metrics
# Saved lumberton-nc metrics
# Saved lawrence-ks metrics
# Saved goldsboro-nc metrics
# Saved watertown-ny metrics
# Saved sheboygan-wi metrics
# Saved weirton-wv metrics
# Saved bozeman-mt metrics
# Saved anniston-al metrics
# Saved beckley-wv metrics
# Saved williamsport-pa metrics
# Saved brunswick-ga metrics
# Saved california-md metrics
# Saved twinfalls-id metrics
# Saved cookeville-tn metrics
# Saved muncie-in metrics
# Saved michigancity-in metrics
# Saved roseburg-or metrics
# Saved longview-wa metrics
# Saved kankakee-il metrics
# Saved showlow-az metrics
# Saved richmond-ky metrics
# Saved whitewater-wi metrics
# Saved grandforks-nd metrics
# Saved decatur-il metrics
# Saved lagrange-ga metrics
# Saved baycity-mi metrics
# Saved fonddulac-wi metrics
# Saved gettysburg-pa metrics
# Saved danville-va metrics
# Saved mankato-mn metrics
# Saved lima-oh metrics
# Saved salem-oh metrics
# Saved truckee-ca metrics
# Saved sebring-fl metrics
# Saved hotsprings-ar metrics
# Saved adrian-mi metrics
# Saved dubuque-ia metrics
# Saved pinehurst-nc metrics
# Saved paducah-ky metrics
# Saved victoria-tx metrics
# Saved rome-ga metrics
# Saved sevierville-tn metrics
# Saved moseslake-wa metrics
# Saved ashtabula-oh metrics
# Saved capegirardeau-mo metrics
# Saved brainerd-mn metrics
# Saved cumberland-md metrics
# Saved oceancity-nj metrics
# Saved corvallis-or metrics
# Saved pocatello-id metrics
# Saved corning-ny metrics
# Saved newphiladelphia-oh metrics
# Saved hermiston-or metrics
# Saved clarksburg-wv metrics
# Saved parkersburg-wv metrics
# Saved grantspass-or metrics
# Saved zanesville-oh metrics
# Saved newcastle-pa metrics
# Saved oakharbor-wa metrics
# Saved indiana-pa metrics
# Saved midland-mi metrics
# Saved kokomo-in metrics
# Saved bloomsburg-pa metrics
# Saved keywest-fl metrics
# Saved stillwater-ok metrics
# Saved columbus-in metrics
# Saved athens-tx metrics
# Saved centralia-wa metrics
# Saved hinesville-ga metrics
# Saved warsaw-in metrics
# Saved plattsburgh-ny metrics
# Saved statesboro-ga metrics
# Saved wilson-nc metrics
# Saved glenwoodsprings-co metrics
# Saved seneca-sc metrics
# Saved olean-ny metrics
# Saved chillicothe-oh metrics
# Saved grandisland-ne metrics
# Saved portangeles-wa metrics
# Saved huntsville-tx metrics
# Saved quincy-il metrics
# Saved sandusky-oh metrics
# Saved findlay-oh metrics
# Saved frankfort-ky metrics
# Saved aberdeen-wa metrics
# Saved somerset-pa metrics
# Saved kapaa-hi metrics
# Saved palatka-fl metrics
# Saved shawnee-ok metrics
# Saved mountairy-nc metrics
# Saved greenwood-sc metrics
# Saved lakecity-fl metrics
# Saved klamathfalls-or metrics
# Saved moreheadcity-nc metrics
# Saved clearlake-ca metrics
# Saved farmington-mo metrics
# Saved muskogee-ok metrics
# Saved marion-in metrics
# Saved marquette-mi metrics
# Saved northwilkesboro-nc metrics
# Saved mountpleasant-mi metrics
# Saved marion-oh metrics
# Saved baraboo-wi metrics
# Saved redbluff-ca metrics
# Saved shelton-wa metrics
# Saved coosbay-or metrics
# Saved forestcity-nc metrics
# Saved rexburg-id metrics
# Saved lewiston-id metrics
# Saved georgetown-sc metrics
# Saved sanford-nc metrics
# Saved enid-ok metrics
# Saved mountvernon-oh metrics
# Saved wallawalla-wa metrics
# Saved albemarle-nc metrics
# Saved hudson-ny metrics
# Saved sturgis-mi metrics
# Saved rutland-vt metrics
# Saved crossville-tn metrics
# Saved salina-ks metrics
# Saved marietta-oh metrics
# Saved fergusfalls-mn metrics
# Saved oneonta-ny metrics
# Saved ardmore-ok metrics
# Saved fortmadison-ia metrics
# Saved fernley-nv metrics
# Saved carsoncity-nv metrics
# Saved calhoun-ga metrics
# Saved cullowhee-nc metrics
# Saved fairmont-wv metrics
# Saved ontario-or metrics
# Saved sterling-il metrics
# Saved branson-mo metrics
# Saved jasper-in metrics
# Saved edwards-co metrics
# Saved durango-co metrics
# Saved kinston-nc metrics
# Saved sonora-ca metrics
# Saved elko-nv metrics
# Saved danville-ky metrics
# Saved glasgow-ky metrics
# Saved stmarys-ga metrics
# Saved boone-nc metrics
# Saved gloversville-ny metrics
# Saved elizabethcity-nc metrics
# Saved payson-az metrics
# Saved ashland-oh metrics
# Saved milledgeville-ga metrics
# Saved kerrville-tx metrics
# Saved bartlesville-ok metrics
# Saved greenville-oh metrics
# Saved rochelle-il metrics
# Saved oilcity-pa metrics
# Saved masoncity-ia metrics
# Saved newport-or metrics
# Saved gardnervilleranchos-nv metrics
# Saved canoncity-co metrics
# Saved newcastle-in metrics
# Saved norfolk-ne metrics
# Saved cadillac-mi metrics
# Saved sidney-oh metrics
# Saved redwing-mn metrics
# Saved nogales-az metrics
# Saved tahlequah-ok metrics
# Saved kendallville-in metrics
# Saved montrose-co metrics
# Saved mountsterling-ky metrics
# Saved clinton-ia metrics
# Saved plymouth-in metrics
# Saved bemidji-mn metrics
# Saved bellefontaine-oh metrics
# Saved durant-ok metrics
# Saved cornelia-ga metrics
# Saved hillsdale-mi metrics
# Saved burlington-ia metrics
# Saved freeport-il metrics
# Saved rolla-mo metrics
# Saved ellensburg-wa metrics
# Saved poncacity-ok metrics
# Saved mcalester-ok metrics
# Saved muscatine-ia metrics
# Saved duncan-ok metrics
# Saved cedartown-ga metrics
# Saved astoria-or metrics
# Saved bigstonegap-va metrics
# Saved bigrapids-mi metrics
# Saved okeechobee-fl metrics
# Saved clewiston-fl metrics
# Saved brownwood-tx metrics
# Saved crawfordsville-in metrics
# Saved scottsbluff-ne metrics
# Saved fremont-ne metrics
# Saved killdevilhills-nc metrics
# Saved northplatte-ne metrics
# Saved brenham-tx metrics
# Saved angola-in metrics
# Saved breckenridge-co metrics
# Saved miami-ok metrics
# Saved toccoa-ga metrics
# Saved prineville-or metrics

# %% [markdown]
# This data is almost ready, but I need to add the sales to list data, which is organized by state instead of city.

# %%
sales_to_list
# Out:
#     Unnamed: 0        AL        AR        AZ        CA        CO        CT  \
# 0   2018-01-31  0.973026  0.974500  0.975310  0.995232  0.991388  0.971217
# 1   2018-02-28  0.976366  0.972710  0.981197  0.997403  0.993109  0.970068
# 2   2018-03-31  0.980754  0.979897  0.983725  1.000017  0.996926  0.973234
# 3   2018-04-30  0.986284  0.980898  0.982381  1.000998  0.997602  0.976208
# 4   2018-05-31  0.983696  0.979413  0.985022  0.999937  0.997888  0.978548
# ..         ...       ...       ...       ...       ...       ...       ...
# 70  2023-11-30  0.982595  0.975823  0.982199  0.995849  0.988147  1.007997
# 71  2023-12-31  0.979914  0.983080  0.982363  0.991588  0.983208  1.004903
# 72  2024-01-31  0.979376  0.975026  0.980264  0.994182  0.984198  1.000701
# 73  2024-02-29  0.982972  0.983369  0.980733  0.997398  0.985470  1.002922
# 74  2024-03-31  0.984837  0.987260  0.984692  0.998149  0.990735  1.010143
#
#           DE        FL        GA  ...        SD        TN        TX        UT  \
# 0   0.985771  0.965779  0.978232  ...  0.983807  0.972172  0.973343  0.990170
# 1   0.973206  0.968798  0.975542  ...  0.979381  0.973165  0.978543  0.990959
# 2   0.975674  0.971176  0.979092  ...  0.981030  0.978066  0.983998  0.992647
# 3   0.974315  0.971488  0.978387  ...  0.984962  0.982652  0.986519  0.992766
# 4   0.987668  0.973523  0.981614  ...  0.987747  0.981954  0.985405  0.992051
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 70  0.992845  0.973371  0.990083  ...  0.993689  0.979792  0.979522  0.986116
# 71  0.991427  0.971419  0.987363  ...  0.981845  0.977592  0.973383  0.984875
# 72  0.989130  0.967882  0.986412  ...  0.983022  0.977089  0.975152  0.983773
# 73  0.991549  0.968467  0.989845  ...  0.993446  0.980146  0.978564  0.990308
# 74  0.992473  0.970533  0.987943  ...  0.984615  0.981708  0.977597  0.990041
#
#           VA        VT        WA        WI        WV        WY
# 0   0.982654       NaN  0.991411  0.979425  0.969691  0.996063
# 1   0.987141       NaN  0.992882  0.983908  0.969977  1.000000
# 2   0.988936       NaN  0.998972  0.992666  0.967764  1.000000
# 3   0.990091       NaN  0.999631  0.997509  0.964423  1.000000
# 4   0.992521       NaN  1.001122  1.000080  0.964286  0.997212
# ..       ...       ...       ...       ...       ...       ...
# 70  0.996671  1.003810  0.991303  1.000000  0.971460  0.973833
# 71  0.991563  1.000000  0.989669  0.997506  0.973473  0.975011
# 72  0.990398  0.996999  0.994027  0.993989  0.961698  0.976585
# 73  0.993610  0.997058  0.994948  1.000767  0.961296  0.965448
# 74  0.995573  1.000000  0.994693  1.001914  0.975351  0.986006
#
# [75 rows x 50 columns]

# %%
common_cities[2:5]
# Out:
# ['Huntsville, TX', 'Richmond, KY', 'Indianapolis, IN']

# %%
for city in common_cities:
  if city != 'United States':
    city = city.replace(", ", "-").replace(" ", "").replace(".","").replace('-¦', 'n').lower()
    print(city)
    state = city.split('-')[1].upper()
    print(state)
    df = pd.read_csv(f'city_metrics_2/{city}_metrics.csv')
    if state == 'DC':
      state = 'VA'
    df['sales_to_list'] = sales_to_list[state]
    df.to_csv(f'city_metrics_3/{city}_metrics.csv', index=True)
    print(f'Saved {city} metrics')
  else:
    city = city.replace(" ", "").lower()
    df.to_csv(f'city_metrics_3/{city}_metrics.csv', index=True)
    print(f'Saved {city} metrics')
# Out:
# batonrouge-la
# LA
# Saved batonrouge-la metrics
# muncie-in
# IN
# Saved muncie-in metrics
# huntsville-tx
# TX
# Saved huntsville-tx metrics
# richmond-ky
# KY
# Saved richmond-ky metrics
# indianapolis-in
# IN
# Saved indianapolis-in metrics
# zanesville-oh
# OH
# Saved zanesville-oh metrics
# fairmont-wv
# WV
# Saved fairmont-wv metrics
# poncacity-ok
# OK
# Saved poncacity-ok metrics
# coosbay-or
# OR
# Saved coosbay-or metrics
# manhattan-ks
# KS
# Saved manhattan-ks metrics
# elkhart-in
# IN
# Saved elkhart-in metrics
# mankato-mn
# MN
# Saved mankato-mn metrics
# bowlinggreen-ky
# KY
# Saved bowlinggreen-ky metrics
# winchester-va
# VA
# Saved winchester-va metrics
# ashland-oh
# OH
# Saved ashland-oh metrics
# rochester-mn
# MN
# Saved rochester-mn metrics
# wilmington-nc
# NC
# Saved wilmington-nc metrics
# columbus-ga
# GA
# Saved columbus-ga metrics
# gardnervilleranchos-nv
# NV
# Saved gardnervilleranchos-nv metrics
# nashville-tn
# TN
# Saved nashville-tn metrics
# scottsbluff-ne
# NE
# Saved scottsbluff-ne metrics
# atlanticcity-nj
# NJ
# Saved atlanticcity-nj metrics
# tucson-az
# AZ
# Saved tucson-az metrics
# monroe-mi
# MI
# Saved monroe-mi metrics
# milwaukee-wi
# WI
# Saved milwaukee-wi metrics
# albuquerque-nm
# NM
# Saved albuquerque-nm metrics
# tyler-tx
# TX
# Saved tyler-tx metrics
# stgeorge-ut
# UT
# Saved stgeorge-ut metrics
# stmarys-ga
# GA
# Saved stmarys-ga metrics
# grandjunction-co
# CO
# Saved grandjunction-co metrics
# fremont-ne
# NE
# Saved fremont-ne metrics
# hartford-ct
# CT
# Saved hartford-ct metrics
# mobile-al
# AL
# Saved mobile-al metrics
# burlington-nc
# NC
# Saved burlington-nc metrics
# collegestation-tx
# TX
# Saved collegestation-tx metrics
# urbanhonolulu-hi
# HI
# Saved urbanhonolulu-hi metrics
# macon-ga
# GA
# Saved macon-ga metrics
# shreveport-la
# LA
# Saved shreveport-la metrics
# newbern-nc
# NC
# Saved newbern-nc metrics
# philadelphia-pa
# PA
# Saved philadelphia-pa metrics
# birmingham-al
# AL
# Saved birmingham-al metrics
# durango-co
# CO
# Saved durango-co metrics
# santamaria-ca
# CA
# Saved santamaria-ca metrics
# bend-or
# OR
# Saved bend-or metrics
# thevillages-fl
# FL
# Saved thevillages-fl metrics
# muskogee-ok
# OK
# Saved muskogee-ok metrics
# springfield-oh
# OH
# Saved springfield-oh metrics
# naples-fl
# FL
# Saved naples-fl metrics
# sevierville-tn
# TN
# Saved sevierville-tn metrics
# mountairy-nc
# NC
# Saved mountairy-nc metrics
# miami-fl
# FL
# Saved miami-fl metrics
# toledo-oh
# OH
# Saved toledo-oh metrics
# bozeman-mt
# MT
# Saved bozeman-mt metrics
# miami-ok
# OK
# Saved miami-ok metrics
# worcester-ma
# MA
# Saved worcester-ma metrics
# newcastle-in
# IN
# Saved newcastle-in metrics
# grantspass-or
# OR
# Saved grantspass-or metrics
# sumter-sc
# SC
# Saved sumter-sc metrics
# ashtabula-oh
# OH
# Saved ashtabula-oh metrics
# hillsdale-mi
# MI
# Saved hillsdale-mi metrics
# portland-me
# ME
# Saved portland-me metrics
# rolla-mo
# MO
# Saved rolla-mo metrics
# flint-mi
# MI
# Saved flint-mi metrics
# lasvegas-nv
# NV
# Saved lasvegas-nv metrics
# lagrange-ga
# GA
# Saved lagrange-ga metrics
# hickory-nc
# NC
# Saved hickory-nc metrics
# columbia-mo
# MO
# Saved columbia-mo metrics
# clearlake-ca
# CA
# Saved clearlake-ca metrics
# fresno-ca
# CA
# Saved fresno-ca metrics
# burlington-ia
# IA
# Saved burlington-ia metrics
# bigrapids-mi
# MI
# Saved bigrapids-mi metrics
# cookeville-tn
# TN
# Saved cookeville-tn metrics
# albany-or
# OR
# Saved albany-or metrics
# lansing-mi
# MI
# Saved lansing-mi metrics
# elizabethtown-ky
# KY
# Saved elizabethtown-ky metrics
# santacruz-ca
# CA
# Saved santacruz-ca metrics
# wilson-nc
# NC
# Saved wilson-nc metrics
# morgantown-wv
# WV
# Saved morgantown-wv metrics
# capecoral-fl
# FL
# Saved capecoral-fl metrics
# bremerton-wa
# WA
# Saved bremerton-wa metrics
# columbus-oh
# OH
# Saved columbus-oh metrics
# yuma-az
# AZ
# Saved yuma-az metrics
# stcloud-mn
# MN
# Saved stcloud-mn metrics
# jacksonville-fl
# FL
# Saved jacksonville-fl metrics
# tuscaloosa-al
# AL
# Saved tuscaloosa-al metrics
# cedartown-ga
# GA
# Saved cedartown-ga metrics
# findlay-oh
# OH
# Saved findlay-oh metrics
# london-ky
# KY
# Saved london-ky metrics
# cleveland-oh
# OH
# Saved cleveland-oh metrics
# lynchburg-va
# VA
# Saved lynchburg-va metrics
# merced-ca
# CA
# Saved merced-ca metrics
# sidney-oh
# OH
# Saved sidney-oh metrics
# louisville-ky
# KY
# Saved louisville-ky metrics
# pottsville-pa
# PA
# Saved pottsville-pa metrics
# bakersfield-ca
# CA
# Saved bakersfield-ca metrics
# auburn-al
# AL
# Saved auburn-al metrics
# salinas-ca
# CA
# Saved salinas-ca metrics
# bellefontaine-oh
# OH
# Saved bellefontaine-oh metrics
# battlecreek-mi
# MI
# Saved battlecreek-mi metrics
# desmoines-ia
# IA
# Saved desmoines-ia metrics
# annarbor-mi
# MI
# Saved annarbor-mi metrics
# yubacity-ca
# CA
# Saved yubacity-ca metrics
# norwich-ct
# CT
# Saved norwich-ct metrics
# myrtlebeach-sc
# SC
# Saved myrtlebeach-sc metrics
# joplin-mo
# MO
# Saved joplin-mo metrics
# pinehurst-nc
# NC
# Saved pinehurst-nc metrics
# newphiladelphia-oh
# OH
# Saved newphiladelphia-oh metrics
# edwards-co
# CO
# Saved edwards-co metrics
# wheeling-wv
# WV
# Saved wheeling-wv metrics
# showlow-az
# AZ
# Saved showlow-az metrics
# salem-or
# OR
# Saved salem-or metrics
# payson-az
# AZ
# Saved payson-az metrics
# kokomo-in
# IN
# Saved kokomo-in metrics
# prineville-or
# OR
# Saved prineville-or metrics
# danville-va
# VA
# Saved danville-va metrics
# amarillo-tx
# TX
# Saved amarillo-tx metrics
# tallahassee-fl
# FL
# Saved tallahassee-fl metrics
# cincinnati-oh
# OH
# Saved cincinnati-oh metrics
# champaign-il
# IL
# Saved champaign-il metrics
# medford-or
# OR
# Saved medford-or metrics
# brenham-tx
# TX
# Saved brenham-tx metrics
# chambersburg-pa
# PA
# Saved chambersburg-pa metrics
# peoria-il
# IL
# Saved peoria-il metrics
# savannah-ga
# GA
# Saved savannah-ga metrics
# charleston-wv
# WV
# Saved charleston-wv metrics
# cornelia-ga
# GA
# Saved cornelia-ga metrics
# lewiston-id
# ID
# Saved lewiston-id metrics
# brownwood-tx
# TX
# Saved brownwood-tx metrics
# traversecity-mi
# MI
# Saved traversecity-mi metrics
# saltlakecity-ut
# UT
# Saved saltlakecity-ut metrics
# alexandria-la
# LA
# Saved alexandria-la metrics
# lancaster-pa
# PA
# Saved lancaster-pa metrics
# newport-or
# OR
# Saved newport-or metrics
# janesville-wi
# WI
# Saved janesville-wi metrics
# palmbay-fl
# FL
# Saved palmbay-fl metrics
# littlerock-ar
# AR
# Saved littlerock-ar metrics
# charlottesville-va
# VA
# Saved charlottesville-va metrics
# lubbock-tx
# TX
# Saved lubbock-tx metrics
# wausau-wi
# WI
# Saved wausau-wi metrics
# hermiston-or
# OR
# Saved hermiston-or metrics
# oxnard-ca
# CA
# Saved oxnard-ca metrics
# huntsville-al
# AL
# Saved huntsville-al metrics
# oceancity-nj
# NJ
# Saved oceancity-nj metrics
# shelton-wa
# WA
# Saved shelton-wa metrics
# augusta-me
# ME
# Saved augusta-me metrics
# sacramento-ca
# CA
# Saved sacramento-ca metrics
# topeka-ks
# KS
# Saved topeka-ks metrics
# twinfalls-id
# ID
# Saved twinfalls-id metrics
# phoenix-az
# AZ
# Saved phoenix-az metrics
# tulsa-ok
# OK
# Saved tulsa-ok metrics
# muskegon-mi
# MI
# Saved muskegon-mi metrics
# vallejo-ca
# CA
# Saved vallejo-ca metrics
# muscatine-ia
# IA
# Saved muscatine-ia metrics
# durham-nc
# NC
# Saved durham-nc metrics
# oakharbor-wa
# WA
# Saved oakharbor-wa metrics
# bemidji-mn
# MN
# Saved bemidji-mn metrics
# duncan-ok
# OK
# Saved duncan-ok metrics
# lincoln-ne
# NE
# Saved lincoln-ne metrics
# riverside-ca
# CA
# Saved riverside-ca metrics
# utica-ny
# NY
# Saved utica-ny metrics
# grandforks-nd
# ND
# Saved grandforks-nd metrics
# dover-de
# DE
# Saved dover-de metrics
# cedarrapids-ia
# IA
# Saved cedarrapids-ia metrics
# georgetown-sc
# SC
# Saved georgetown-sc metrics
# norfolk-ne
# NE
# Saved norfolk-ne metrics
# nogales-az
# AZ
# Saved nogales-az metrics
# calhoun-ga
# GA
# Saved calhoun-ga metrics
# jacksonville-nc
# NC
# Saved jacksonville-nc metrics
# tahlequah-ok
# OK
# Saved tahlequah-ok metrics
# williamsport-pa
# PA
# Saved williamsport-pa metrics
# portstlucie-fl
# FL
# Saved portstlucie-fl metrics
# reno-nv
# NV
# Saved reno-nv metrics
# barnstabletown-ma
# MA
# Saved barnstabletown-ma metrics
# Saved unitedstates metrics
# bellingham-wa
# WA
# Saved bellingham-wa metrics
# pensacola-fl
# FL
# Saved pensacola-fl metrics
# houston-tx
# TX
# Saved houston-tx metrics
# oneonta-ny
# NY
# Saved oneonta-ny metrics
# santarosa-ca
# CA
# Saved santarosa-ca metrics
# waco-tx
# TX
# Saved waco-tx metrics
# greenville-sc
# SC
# Saved greenville-sc metrics
# warnerrobins-ga
# GA
# Saved warnerrobins-ga metrics
# allentown-pa
# PA
# Saved allentown-pa metrics
# dubuque-ia
# IA
# Saved dubuque-ia metrics
# adrian-mi
# MI
# Saved adrian-mi metrics
# appleton-wi
# WI
# Saved appleton-wi metrics
# goldsboro-nc
# NC
# Saved goldsboro-nc metrics
# marietta-oh
# OH
# Saved marietta-oh metrics
# kinston-nc
# NC
# Saved kinston-nc metrics
# hilo-hi
# HI
# Saved hilo-hi metrics
# fortcollins-co
# CO
# Saved fortcollins-co metrics
# sandusky-oh
# OH
# Saved sandusky-oh metrics
# jackson-ms
# MS
# Saved jackson-ms metrics
# fortsmith-ar
# AR
# Saved fortsmith-ar metrics
# jackson-mi
# MI
# Saved jackson-mi metrics
# erie-pa
# PA
# Saved erie-pa metrics
# seneca-sc
# SC
# Saved seneca-sc metrics
# orlando-fl
# FL
# Saved orlando-fl metrics
# greeley-co
# CO
# Saved greeley-co metrics
# mountvernon-oh
# OH
# Saved mountvernon-oh metrics
# okeechobee-fl
# FL
# Saved okeechobee-fl metrics
# lafayette-la
# LA
# Saved lafayette-la metrics
# redding-ca
# CA
# Saved redding-ca metrics
# gulfport-ms
# MS
# Saved gulfport-ms metrics
# durant-ok
# OK
# Saved durant-ok metrics
# corning-ny
# NY
# Saved corning-ny metrics
# ocala-fl
# FL
# Saved ocala-fl metrics
# klamathfalls-or
# OR
# Saved klamathfalls-or metrics
# baltimore-md
# MD
# Saved baltimore-md metrics
# clarksburg-wv
# WV
# Saved clarksburg-wv metrics
# clarksville-tn
# TN
# Saved clarksville-tn metrics
# roseburg-or
# OR
# Saved roseburg-or metrics
# baraboo-wi
# WI
# Saved baraboo-wi metrics
# northport-fl
# FL
# Saved northport-fl metrics
# southbend-in
# IN
# Saved southbend-in metrics
# idahofalls-id
# ID
# Saved idahofalls-id metrics
# farmington-mo
# MO
# Saved farmington-mo metrics
# chico-ca
# CA
# Saved chico-ca metrics
# abilene-tx
# TX
# Saved abilene-tx metrics
# glensfalls-ny
# NY
# Saved glensfalls-ny metrics
# virginiabeach-va
# VA
# Saved virginiabeach-va metrics
# iowacity-ia
# IA
# Saved iowacity-ia metrics
# lakecity-fl
# FL
# Saved lakecity-fl metrics
# beaumont-tx
# TX
# Saved beaumont-tx metrics
# lexington-ky
# KY
# Saved lexington-ky metrics
# pittsfield-ma
# MA
# Saved pittsfield-ma metrics
# kennewick-wa
# WA
# Saved kennewick-wa metrics
# kalamazoo-mi
# MI
# Saved kalamazoo-mi metrics
# keywest-fl
# FL
# Saved keywest-fl metrics
# northwilkesboro-nc
# NC
# Saved northwilkesboro-nc metrics
# tampa-fl
# FL
# Saved tampa-fl metrics
# athens-tx
# TX
# Saved athens-tx metrics
# watertown-ny
# NY
# Saved watertown-ny metrics
# anniston-al
# AL
# Saved anniston-al metrics
# deltona-fl
# FL
# Saved deltona-fl metrics
# bloomington-in
# IN
# Saved bloomington-in metrics
# blacksburg-va
# VA
# Saved blacksburg-va metrics
# montrose-co
# CO
# Saved montrose-co metrics
# marion-in
# IN
# Saved marion-in metrics
# hudson-ny
# NY
# Saved hudson-ny metrics
# ogden-ut
# UT
# Saved ogden-ut metrics
# columbia-sc
# SC
# Saved columbia-sc metrics
# harrisburg-pa
# PA
# Saved harrisburg-pa metrics
# capegirardeau-mo
# MO
# Saved capegirardeau-mo metrics
# springfield-mo
# MO
# Saved springfield-mo metrics
# killeen-tx
# TX
# Saved killeen-tx metrics
# albemarle-nc
# NC
# Saved albemarle-nc metrics
# modesto-ca
# CA
# Saved modesto-ca metrics
# redbluff-ca
# CA
# Saved redbluff-ca metrics
# sebring-fl
# FL
# Saved sebring-fl metrics
# scranton-pa
# PA
# Saved scranton-pa metrics
# ellensburg-wa
# WA
# Saved ellensburg-wa metrics
# homosassasprings-fl
# FL
# Saved homosassasprings-fl metrics
# kankakee-il
# IL
# Saved kankakee-il metrics
# bloomington-il
# IL
# Saved bloomington-il metrics
# roanoke-va
# VA
# Saved roanoke-va metrics
# elko-nv
# NV
# Saved elko-nv metrics
# harrisonburg-va
# VA
# Saved harrisonburg-va metrics
# sanjose-ca
# CA
# Saved sanjose-ca metrics
# spartanburg-sc
# SC
# Saved spartanburg-sc metrics
# sturgis-mi
# MI
# Saved sturgis-mi metrics
# oilcity-pa
# PA
# Saved oilcity-pa metrics
# marquette-mi
# MI
# Saved marquette-mi metrics
# kingston-ny
# NY
# Saved kingston-ny metrics
# hinesville-ga
# GA
# Saved hinesville-ga metrics
# mountsterling-ky
# KY
# Saved mountsterling-ky metrics
# hagerstown-md
# MD
# Saved hagerstown-md metrics
# canoncity-co
# CO
# Saved canoncity-co metrics
# atlanta-ga
# GA
# Saved atlanta-ga metrics
# coloradosprings-co
# CO
# Saved coloradosprings-co metrics
# olympia-wa
# WA
# Saved olympia-wa metrics
# brainerd-mn
# MN
# Saved brainerd-mn metrics
# bigstonegap-va
# VA
# Saved bigstonegap-va metrics
# austin-tx
# TX
# Saved austin-tx metrics
# salem-oh
# OH
# Saved salem-oh metrics
# frankfort-ky
# KY
# Saved frankfort-ky metrics
# staunton-va
# VA
# Saved staunton-va metrics
# grandisland-ne
# NE
# Saved grandisland-ne metrics
# knoxville-tn
# TN
# Saved knoxville-tn metrics
# lafayette-in
# IN
# Saved lafayette-in metrics
# coeurd'alene-id
# ID
# Saved coeurd'alene-id metrics
# michigancity-in
# IN
# Saved michigancity-in metrics
# lascruces-nm
# NM
# Saved lascruces-nm metrics
# pittsburgh-pa
# PA
# Saved pittsburgh-pa metrics
# greensboro-nc
# NC
# Saved greensboro-nc metrics
# burlington-vt
# VT
# Saved burlington-vt metrics
# cleveland-tn
# TN
# Saved cleveland-tn metrics
# lawrence-ks
# KS
# Saved lawrence-ks metrics
# chattanooga-tn
# TN
# Saved chattanooga-tn metrics
# rapidcity-sd
# SD
# Saved rapidcity-sd metrics
# longview-wa
# WA
# Saved longview-wa metrics
# fergusfalls-mn
# MN
# Saved fergusfalls-mn metrics
# fernley-nv
# NV
# Saved fernley-nv metrics
# madison-wi
# WI
# Saved madison-wi metrics
# hiltonheadisland-sc
# SC
# Saved hiltonheadisland-sc metrics
# reading-pa
# PA
# Saved reading-pa metrics
# wenatchee-wa
# WA
# Saved wenatchee-wa metrics
# kendallville-in
# IN
# Saved kendallville-in metrics
# glenwoodsprings-co
# CO
# Saved glenwoodsprings-co metrics
# oshkosh-wi
# WI
# Saved oshkosh-wi metrics
# evansville-in
# IN
# Saved evansville-in metrics
# boston-ma
# MA
# Saved boston-ma metrics
# stockton-ca
# CA
# Saved stockton-ca metrics
# eugene-or
# OR
# Saved eugene-or metrics
# bloomsburg-pa
# PA
# Saved bloomsburg-pa metrics
# brownsville-tx
# TX
# Saved brownsville-tx metrics
# elpaso-tx
# TX
# Saved elpaso-tx metrics
# fonddulac-wi
# WI
# Saved fonddulac-wi metrics
# brunswick-ga
# GA
# Saved brunswick-ga metrics
# visalia-ca
# CA
# Saved visalia-ca metrics
# rochester-ny
# NY
# Saved rochester-ny metrics
# racine-wi
# WI
# Saved racine-wi metrics
# bridgeport-ct
# CT
# Saved bridgeport-ct metrics
# milledgeville-ga
# GA
# Saved milledgeville-ga metrics
# sanantonio-tx
# TX
# Saved sanantonio-tx metrics
# chillicothe-oh
# OH
# Saved chillicothe-oh metrics
# sonora-ca
# CA
# Saved sonora-ca metrics
# danville-ky
# KY
# Saved danville-ky metrics
# enid-ok
# OK
# Saved enid-ok metrics
# sanluisobispo-ca
# CA
# Saved sanluisobispo-ca metrics
# plymouth-in
# IN
# Saved plymouth-in metrics
# paducah-ky
# KY
# Saved paducah-ky metrics
# asheville-nc
# NC
# Saved asheville-nc metrics
# madera-ca
# CA
# Saved madera-ca metrics
# chicago-il
# IL
# Saved chicago-il metrics
# raleigh-nc
# NC
# Saved raleigh-nc metrics
# carsoncity-nv
# NV
# Saved carsoncity-nv metrics
# decatur-il
# IL
# Saved decatur-il metrics
# terrehaute-in
# IN
# Saved terrehaute-in metrics
# jasper-in
# IN
# Saved jasper-in metrics
# gainesville-fl
# FL
# Saved gainesville-fl metrics
# branson-mo
# MO
# Saved branson-mo metrics
# sheboygan-wi
# WI
# Saved sheboygan-wi metrics
# quincy-il
# IL
# Saved quincy-il metrics
# mcallen-tx
# TX
# Saved mcallen-tx metrics
# breckenridge-co
# CO
# Saved breckenridge-co metrics
# sanfrancisco-ca
# CA
# Saved sanfrancisco-ca metrics
# providence-ri
# RI
# Saved providence-ri metrics
# omaha-ne
# NE
# Saved omaha-ne metrics
# yakima-wa
# WA
# Saved yakima-wa metrics
# canton-oh
# OH
# Saved canton-oh metrics
# greenbay-wi
# WI
# Saved greenbay-wi metrics
# ontario-or
# OR
# Saved ontario-or metrics
# somerset-pa
# PA
# Saved somerset-pa metrics
# augusta-ga
# GA
# Saved augusta-ga metrics
# sierravista-az
# AZ
# Saved sierravista-az metrics
# corvallis-or
# OR
# Saved corvallis-or metrics
# athens-ga
# GA
# Saved athens-ga metrics
# rome-ga
# GA
# Saved rome-ga metrics
# hotsprings-ar
# AR
# Saved hotsprings-ar metrics
# midland-mi
# MI
# Saved midland-mi metrics
# shawnee-ok
# OK
# Saved shawnee-ok metrics
# oklahomacity-ok
# OK
# Saved oklahomacity-ok metrics
# kerrville-tx
# TX
# Saved kerrville-tx metrics
# holland-mi
# MI
# Saved holland-mi metrics
# provo-ut
# UT
# Saved provo-ut metrics
# niles-mi
# MI
# Saved niles-mi metrics
# eauclaire-wi
# WI
# Saved eauclaire-wi metrics
# saginaw-mi
# MI
# Saved saginaw-mi metrics
# farmington-nm
# NM
# Saved farmington-nm metrics
# stillwater-ok
# OK
# Saved stillwater-ok metrics
# aberdeen-wa
# WA
# Saved aberdeen-wa metrics
# rockford-il
# IL
# Saved rockford-il metrics
# spokane-wa
# WA
# Saved spokane-wa metrics
# cumberland-md
# MD
# Saved cumberland-md metrics
# syracuse-ny
# NY
# Saved syracuse-ny metrics
# minneapolis-mn
# MN
# Saved minneapolis-mn metrics
# york-pa
# PA
# Saved york-pa metrics
# mcalester-ok
# OK
# Saved mcalester-ok metrics
# sherman-tx
# TX
# Saved sherman-tx metrics
# sterling-il
# IL
# Saved sterling-il metrics
# corpuschristi-tx
# TX
# Saved corpuschristi-tx metrics
# kingsport-tn
# TN
# Saved kingsport-tn metrics
# longview-tx
# TX
# Saved longview-tx metrics
# forestcity-nc
# NC
# Saved forestcity-nc metrics
# youngstown-oh
# OH
# Saved youngstown-oh metrics
# seattle-wa
# WA
# Saved seattle-wa metrics
# charleston-sc
# SC
# Saved charleston-sc metrics
# siouxcity-ia
# IA
# Saved siouxcity-ia metrics
# crawfordsville-in
# IN
# Saved crawfordsville-in metrics
# jamestown-ny
# NY
# Saved jamestown-ny metrics
# salisbury-md
# MD
# Saved salisbury-md metrics
# grandrapids-mi
# MI
# Saved grandrapids-mi metrics
# ames-ia
# IA
# Saved ames-ia metrics
# sandiego-ca
# CA
# Saved sandiego-ca metrics
# boone-nc
# NC
# Saved boone-nc metrics
# kahului-hi
# HI
# Saved kahului-hi metrics
# moseslake-wa
# WA
# Saved moseslake-wa metrics
# weirton-wv
# WV
# Saved weirton-wv metrics
# olean-ny
# NY
# Saved olean-ny metrics
# portland-or
# OR
# Saved portland-or metrics
# california-md
# MD
# Saved california-md metrics
# montgomery-al
# AL
# Saved montgomery-al metrics
# statecollege-pa
# PA
# Saved statecollege-pa metrics
# palatka-fl
# FL
# Saved palatka-fl metrics
# statesboro-ga
# GA
# Saved statesboro-ga metrics
# stjoseph-mo
# MO
# Saved stjoseph-mo metrics
# mountpleasant-mi
# MI
# Saved mountpleasant-mi metrics
# panamacity-fl
# FL
# Saved panamacity-fl metrics
# eaststroudsburg-pa
# PA
# Saved eaststroudsburg-pa metrics
# monroe-la
# LA
# Saved monroe-la metrics
# pocatello-id
# ID
# Saved pocatello-id metrics
# truckee-ca
# CA
# Saved truckee-ca metrics
# glasgow-ky
# KY
# Saved glasgow-ky metrics
# baycity-mi
# MI
# Saved baycity-mi metrics
# parkersburg-wv
# WV
# Saved parkersburg-wv metrics
# newcastle-pa
# PA
# Saved newcastle-pa metrics
# denver-co
# CO
# Saved denver-co metrics
# northplatte-ne
# NE
# Saved northplatte-ne metrics
# davenport-ia
# IA
# Saved davenport-ia metrics
# greenville-oh
# OH
# Saved greenville-oh metrics
# greenville-nc
# NC
# Saved greenville-nc metrics
# detroit-mi
# MI
# Saved detroit-mi metrics
# springfield-ma
# MA
# Saved springfield-ma metrics
# waterloo-ia
# IA
# Saved waterloo-ia metrics
# gettysburg-pa
# PA
# Saved gettysburg-pa metrics
# bangor-me
# ME
# Saved bangor-me metrics
# cadillac-mi
# MI
# Saved cadillac-mi metrics
# lawton-ok
# OK
# Saved lawton-ok metrics
# torrington-ct
# CT
# Saved torrington-ct metrics
# rutland-vt
# VT
# Saved rutland-vt metrics
# fayetteville-nc
# NC
# Saved fayetteville-nc metrics
# valdosta-ga
# GA
# Saved valdosta-ga metrics
# astoria-or
# OR
# Saved astoria-or metrics
# cullowhee-nc
# NC
# Saved cullowhee-nc metrics
# hattiesburg-ms
# MS
# Saved hattiesburg-ms metrics
# napa-ca
# CA
# Saved napa-ca metrics
# pueblo-co
# CO
# Saved pueblo-co metrics
# rochelle-il
# IL
# Saved rochelle-il metrics
# warsaw-in
# IN
# Saved warsaw-in metrics
# manchester-nh
# NH
# Saved manchester-nh metrics
# crossville-tn
# TN
# Saved crossville-tn metrics
# crestview-fl
# FL
# Saved crestview-fl metrics
# wallawalla-wa
# WA
# Saved wallawalla-wa metrics
# ardmore-ok
# OK
# Saved ardmore-ok metrics
# centralia-wa
# WA
# Saved centralia-wa metrics
# richmond-va
# VA
# Saved richmond-va metrics
# binghamton-ny
# NY
# Saved binghamton-ny metrics
# boulder-co
# CO
# Saved boulder-co metrics
# lakeland-fl
# FL
# Saved lakeland-fl metrics
# clewiston-fl
# FL
# Saved clewiston-fl metrics
# newhaven-ct
# CT
# Saved newhaven-ct metrics
# boisecity-id
# ID
# Saved boisecity-id metrics
# flagstaff-az
# AZ
# Saved flagstaff-az metrics
# bismarck-nd
# ND
# Saved bismarck-nd metrics
# newyork-ny
# NY
# Saved newyork-ny metrics
# lima-oh
# OH
# Saved lima-oh metrics
# jeffersoncity-mo
# MO
# Saved jeffersoncity-mo metrics
# masoncity-ia
# IA
# Saved masoncity-ia metrics
# duluth-mn
# MN
# Saved duluth-mn metrics
# santafe-nm
# NM
# Saved santafe-nm metrics
# salina-ks
# KS
# Saved salina-ks metrics
# wichitafalls-tx
# TX
# Saved wichitafalls-tx metrics
# beckley-wv
# WV
# Saved beckley-wv metrics
# winston-nc
# NC
# Saved winston-nc metrics
# vineland-nj
# NJ
# Saved vineland-nj metrics
# mountvernon-wa
# WA
# Saved mountvernon-wa metrics
# moreheadcity-nc
# NC
# Saved moreheadcity-nc metrics
# albany-ny
# NY
# Saved albany-ny metrics
# stlouis-mo
# MO
# Saved stlouis-mo metrics
# sanford-nc
# NC
# Saved sanford-nc metrics
# fortmadison-ia
# IA
# Saved fortmadison-ia metrics
# mansfield-oh
# OH
# Saved mansfield-oh metrics
# huntington-wv
# WV
# Saved huntington-wv metrics
# bartlesville-ok
# OK
# Saved bartlesville-ok metrics
# kapaa-hi
# HI
# Saved kapaa-hi metrics
# lumberton-nc
# NC
# Saved lumberton-nc metrics
# marion-oh
# OH
# Saved marion-oh metrics
# dallas-tx
# TX
# Saved dallas-tx metrics
# gainesville-ga
# GA
# Saved gainesville-ga metrics
# johnsoncity-tn
# TN
# Saved johnsoncity-tn metrics
# lacrosse-wi
# WI
# Saved lacrosse-wi metrics
# killdevilhills-nc
# NC
# Saved killdevilhills-nc metrics
# toccoa-ga
# GA
# Saved toccoa-ga metrics
# indiana-pa
# PA
# Saved indiana-pa metrics
# washington-dc
# DC
# Saved washington-dc metrics
# portangeles-wa
# WA
# Saved portangeles-wa metrics
# wichita-ks
# KS
# Saved wichita-ks metrics
# trenton-nj
# NJ
# Saved trenton-nj metrics
# concord-nh
# NH
# Saved concord-nh metrics
# gloversville-ny
# NY
# Saved gloversville-ny metrics
# logan-ut
# UT
# Saved logan-ut metrics
# freeport-il
# IL
# Saved freeport-il metrics
# sebastian-fl
# FL
# Saved sebastian-fl metrics
# angola-in
# IN
# Saved angola-in metrics
# victoria-tx
# TX
# Saved victoria-tx metrics
# plattsburgh-ny
# NY
# Saved plattsburgh-ny metrics
# charlotte-nc
# NC
# Saved charlotte-nc metrics
# columbus-in
# IN
# Saved columbus-in metrics
# clinton-ia
# IA
# Saved clinton-ia metrics
# whitewater-wi
# WI
# Saved whitewater-wi metrics
# daphne-al
# AL
# Saved daphne-al metrics
# buffalo-ny
# NY
# Saved buffalo-ny metrics
# billings-mt
# MT
# Saved billings-mt metrics
# memphis-tn
# TN
# Saved memphis-tn metrics
# akron-oh
# OH
# Saved akron-oh metrics
# rockymount-nc
# NC
# Saved rockymount-nc metrics
# fayetteville-ar
# AR
# Saved fayetteville-ar metrics
# lakehavasucity-az
# AZ
# Saved lakehavasucity-az metrics
# neworleans-la
# LA
# Saved neworleans-la metrics
# rexburg-id
# ID
# Saved rexburg-id metrics
# florence-sc
# SC
# Saved florence-sc metrics
# kansascity-mo
# MO
# Saved kansascity-mo metrics
# elizabethcity-nc
# NC
# Saved elizabethcity-nc metrics
# fortwayne-in
# IN
# Saved fortwayne-in metrics
# losangeles-ca
# CA
# Saved losangeles-ca metrics
# greenwood-sc
# SC
# Saved greenwood-sc metrics
# puntagorda-fl
# FL
# Saved puntagorda-fl metrics
# redwing-mn
# MN
# Saved redwing-mn metrics

# %%
import shutil
from google.colab import files

# Define the source and destination paths
source_folder = '/content/city_metrics_3'
zip_file = '/content/city_metrics.zip'

# Create a zip file containing all the files in the content folder
shutil.make_archive(zip_file.replace('.zip', ''), 'zip', source_folder)
# Out:
# '/content/city_metrics.zip'

# %%
files.download(zip_file)
